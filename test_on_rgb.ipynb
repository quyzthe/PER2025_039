# %%
from utils.saliency_v1 import spectral_residual_saliency, compute_bms_saliency, load_rgb_image
import matplotlib.pyplot as plt

img = load_rgb_image('images/apple.jpg')

# Spectral Residual
sr_map = spectral_residual_saliency(img)

# BMS
bms_map = compute_bms_saliency(img)

plt.figure(figsize=(18,6))

plt.subplot(1,3,1)
plt.imshow(img)
plt.title("Original Image")
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(sr_map, cmap='gray')
plt.title("Spectral Residual")
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(bms_map, cmap='gray')
plt.title("BMS Saliency")
plt.axis('off')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from utils.saliency_v1 import spectral_residual_saliency, compute_bms_saliency, load_rgb_image
#       2 import matplotlib.pyplot as plt
#       4 img = load_rgb_image('images/apple.jpg')
#
# ImportError: cannot import name 'load_rgb_image' from 'utils.saliency_v1' (d:\Python_Projects\PER_PROJECT_2025_039\utils\saliency_v1.py)
